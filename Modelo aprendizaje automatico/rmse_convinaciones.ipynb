# %%
import matplotlib.pyplot as plt
import pandas as pd


df1= pd.read_csv('../combinaciones.csv', sep=";")

y=df1.rmse.tolist()
x=df1.Abreviatura.tolist()



plt.plot(x,y, "o")
plt.grid()
plt.xlabel('N Registro')
plt.ylabel('RMSE')
plt.title('RMSE')
plt.show()
